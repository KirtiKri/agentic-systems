# %%
#Declare a variable name and assign your name to it. Print the value of name
name = "Kirti"
print(name)

#Declare two variables a and b with values 10 and 20. Print their sum using an arithmetic operator.
a = 10
b = 20
print(a+b)

#Declare a variable price as 99.99 and print its data type using type().
price = 99.99
print(type(price))

#Declare a variable is_student and assign a boolean value. Print the value.
is_student = True
print(is_student)

#Write a program to check whether a number (e.g., 15) is greater than 10 and print the result.
num = 8
print(num> 10) 

#Calculate and print the result of the expression 2 + 3 * 4. Then modify it using parentheses to change the result
print( 2 + 3 * 4) #result is 14
print( (2 + 3) * 4) #result is 20
# Out:
# Kirti
# 30
# <class 'float'>
# True
# False
# 14
# 20
